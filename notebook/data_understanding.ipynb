# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

DATA_PATH = "../data/raw/FinanKu_Data_All.csv"

df = pd.read_csv(DATA_PATH)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7561 entries, 0 to 7560
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               7561 non-null   int64
#  1   Branch Code               7561 non-null   int64
#  2   City                      7561 non-null   object
#  3   Age                       7561 non-null   int64
#  4   Avg. Annual Income/Month  7561 non-null   int64
#  5   Balance Q1                7561 non-null   float64
#  6   NumOfProducts Q1          7561 non-null   int64
#  7   HasCrCard Q1              7561 non-null   int64
#  8   ActiveMember Q1           7561 non-null   int64
#  9   Balance Q2                7561 non-null   float64
#  10  NumOfProducts Q2          7561 non-null   int64
#  11  HasCrCard Q2              7561 non-null   int64
#  12  ActiveMember Q2           7561 non-null   int64
#  13  Balance Q3                7561 non-null   float64
# ...

# %%
# Dataset
df.shape

rows, cols = df.shape

print(f"Rows : {rows}")
print(f"Columns : {cols}")
# Out:
# Rows : 7561
# Columns : 22

# %%
# Preview
df.head()

# Random Sample
df.sample(5, random_state=45)
# Out:
#       Customer ID  Branch Code      City  Age  Avg. Annual Income/Month  \
# 6432     15738267         1023  Surabaya   59                         0
# 3845     15570060         1024  Surabaya   58                  30000000
# 7084     15782608         1022  Surabaya   37                  13000000
# 1988     15576216         1015   Bandung   61                  25000000
# 1583     15777352         1002   Jakarta   45                  31000000
#
#       Balance Q1  NumOfProducts Q1  HasCrCard Q1  ActiveMember Q1  \
# 6432        0.00                 2             1                1
# 3845        0.00                 2             1                0
# 7084        0.00                 2             1                0
# 1988        0.00                 1             1                0
# 1583        0.00                 2             1                1
#
#        Balance Q2  NumOfProducts Q2  HasCrCard Q2  ActiveMember Q2  \
# ...

# %%
# Data Type Inspection
df.info()
df.dtypes

# Missing Value Inspection
missing = (
    df.isnull()
    .sum()
    .to_frame("Missing Count")
)

missing["Missing Percentage"] = (
    missing["Missing Count"] / len(df) * 100
)

missing.sort_values(
    "Missing Percentage",
    ascending=False
)

# %%
# Duplicate Inspection
df.duplicated().sum()

# Descriptive Statistics
df.describe().T
df.describe(include="object").T

# Unique Values
df.nunique().sort_values()

# Cardinality Check
pd.DataFrame({
    "dtype": df.dtypes,
    "unique": df.nunique(),
    "missing": df.isna().sum()
})

# %%
# Binary Variable Check
binary_columns = [
    "HasCrCard Q1",
    "HasCrCard Q2",
    "HasCrCard Q3",
    "HasCrCard Q4",
    "ActiveMember Q1",
    "ActiveMember Q2",
    "ActiveMember Q3",
    "ActiveMember Q4",
    "Unpaid Tagging"
]

for col in binary_columns:
    print(col)
    print(df[col].value_counts())
    print("-" * 40)

# %%
# Numeric Summary
numeric_summary = df.describe().T

numeric_summary

# Category Summary
df["City"].value_counts()

# Variable Classification
identifier = [
    "Customer ID"
]

categorical = [
    "Branch Code",
    "City"
]

numerical = [
    "Age",
    "Avg. Annual Income/Month",
    "Balance Q1",
    "Balance Q2",
    "Balance Q3",
    "Balance Q4",
    "NumOfProducts Q1",
    "NumOfProducts Q2",
    "NumOfProducts Q3",
    "NumOfProducts Q4"
]

binary = [
    "HasCrCard Q1",
    "HasCrCard Q2",
    "HasCrCard Q3",
    "HasCrCard Q4",
    "ActiveMember Q1",
    "ActiveMember Q2",
    "ActiveMember Q3",
    "ActiveMember Q4"
]

target = [
    "Unpaid Tagging"
]

# Feature Audit
feature_audit = pd.DataFrame({
    "dtype": df.dtypes,
    "unique": df.nunique(),
    "missing": df.isna().sum()
})

# %%
feature_audit

feature_audit.loc["Customer ID", "role"] = "identifier"
# Identifier
feature_audit.loc["Customer ID", "role"] = "Identifier"

# Categorical
feature_audit.loc["Branch Code", "role"] = "Categorical"
feature_audit.loc["City", "role"] = "Categorical"

# Numerical
feature_audit.loc["Age", "role"] = "Numerical"
feature_audit.loc["Avg. Annual Income/Month", "role"] = "Numerical"

feature_audit.loc["Balance Q1", "role"] = "Numerical"
feature_audit.loc["Balance Q2", "role"] = "Numerical"
feature_audit.loc["Balance Q3", "role"] = "Numerical"
feature_audit.loc["Balance Q4", "role"] = "Numerical"

feature_audit.loc["NumOfProducts Q1", "role"] = "Numerical"
feature_audit.loc["NumOfProducts Q2", "role"] = "Numerical"
feature_audit.loc["NumOfProducts Q3", "role"] = "Numerical"
feature_audit.loc["NumOfProducts Q4", "role"] = "Numerical"

# Binary
feature_audit.loc["HasCrCard Q1", "role"] = "Binary"
feature_audit.loc["HasCrCard Q2", "role"] = "Binary"
feature_audit.loc["HasCrCard Q3", "role"] = "Binary"
feature_audit.loc["HasCrCard Q4", "role"] = "Binary"

feature_audit.loc["ActiveMember Q1", "role"] = "Binary"
feature_audit.loc["ActiveMember Q2", "role"] = "Binary"
feature_audit.loc["ActiveMember Q3", "role"] = "Binary"
feature_audit.loc["ActiveMember Q4", "role"] = "Binary"

# Target
feature_audit.loc["Unpaid Tagging", "role"] = "Target"

feature_audit
# Out:
#                             dtype  unique  missing         role
# Customer ID                 int64    7561        0   Identifier
# Branch Code                 int64      18        0  Categorical
# City                       object       3        0  Categorical
# Age                         int64      49        0    Numerical
# Avg. Annual Income/Month    int64      58        0    Numerical
# Balance Q1                float64    4929        0    Numerical
# NumOfProducts Q1            int64       4        0    Numerical
# HasCrCard Q1                int64       2        0       Binary
# ActiveMember Q1             int64       2        0       Binary
# Balance Q2                float64    5562        0    Numerical
# NumOfProducts Q2            int64       5        0    Numerical
# HasCrCard Q2                int64       2        0       Binary
# ActiveMember Q2             int64       2        0       Binary
# Balance Q3                float64    6014        0    Numerical
# ...
